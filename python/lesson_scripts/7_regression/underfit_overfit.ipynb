# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.DataFrame({'x':np.arange(start = -20, stop = 20, step = .2)})

# %%
df['y'] = np.random.normal(df.x*.2+ .1*(df.x)**2, scale = 10)

# %%
plt.scatter(df.x, df.y,  color='black')

# %%
X = df.drop(columns = 'y')
y = df.y

# %%
regr = linear_model.LinearRegression()

# Train the model using the training sets
model1 = regr.fit(X, y)

# %%
model1
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model1_pred = regr.predict(X)

# %%
model1_pred
# Out:
# array([ 8.60568905,  8.65479877,  8.7039085 ,  8.75301822,  8.80212795,
#         8.85123767,  8.90034739,  8.94945712,  8.99856684,  9.04767657,
#         9.09678629,  9.14589602,  9.19500574,  9.24411547,  9.29322519,
#         9.34233491,  9.39144464,  9.44055436,  9.48966409,  9.53877381,
#         9.58788354,  9.63699326,  9.68610299,  9.73521271,  9.78432243,
#         9.83343216,  9.88254188,  9.93165161,  9.98076133, 10.02987106,
#        10.07898078, 10.12809051, 10.17720023, 10.22630995, 10.27541968,
#        10.3245294 , 10.37363913, 10.42274885, 10.47185858, 10.5209683 ,
#        10.57007802, 10.61918775, 10.66829747, 10.7174072 , 10.76651692,
#        10.81562665, 10.86473637, 10.9138461 , 10.96295582, 11.01206554,
#        11.06117527, 11.11028499, 11.15939472, 11.20850444, 11.25761417,
#        11.30672389, 11.35583362, 11.40494334, 11.45405306, 11.50316279,
#        11.55227251, 11.60138224, 11.65049196, 11.69960169, 11.74871141,
# ...

# %%
# Plot outputs
plt.scatter(df.x, df.y,  color='black')
plt.plot(df.x, model1_pred, color='blue', linewidth=3)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(2)

# %%
X_t = poly.fit_transform(X)

# %%
model2 = regr.fit(X_t, y)
model2_pred = regr.predict(X_t)

# %%
# Plot outputs
plt.scatter(df.x, df.y,  color='black')
plt.plot(df.x, model1_pred, color='blue', linewidth=3)
plt.plot(df.x, model2_pred, color='red', linewidth=3)

# %%
df.to_csv('sample2_data.csv', index = False)
